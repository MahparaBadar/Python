# %%
# Absolute path   # Relative path

# %% [markdown]
# ## Absolute Path
#
# * starts from zero
# * tells where the data is from the initial point
#
# `C:\Users\hp 840g6\OneDrive\Desktop\Python\Class 14\mahpara.txt`
#
# For Practice:https://tutorial.eyehunts.com/python/python-file-modes-open-write-append-r-r-w-w-x-etc/

# %% [markdown]
# ## Relative Path
#
# * tells the current path e.g. where is our jupyter running
# * use **pwd** to see the path
# * we use three things for relative path
#    * `./` current location
#    * `./xyz/aa/xyz.txt` moves forward
#    * `../` one folder back e.g. `C:\Users\hp 840g6\OneDrive\Desktop\`
#    * `../../` two folders back e.g. `C:\Users\hp 840g6\OneDrive\`

# %%
pwd
# Out:
# 'C:\\Users\\hp 840g6\\OneDrive\\Desktop\\Python\\Class 14'

# %%
open("./mahpara.txt")   # relative path
# Out:
# <_io.TextIOWrapper name='./mahpara.txt' mode='r' encoding='cp1252'>

# %%
open("./xyz/aa/xyz.txt.txt")  # press tab after folder xyz/it will itself write the inner folder with intellicence
# Out:
# <_io.TextIOWrapper name='./xyz/aa/xyz.txt.txt' mode='r' encoding='cp1252'>

# %%
open("C:\\Users\\hp 840g6\\OneDrive\\Desktop\\Python\\Class 14\\mahpara.txt")  # absolute path
# Out:
# <_io.TextIOWrapper name='C:\\Users\\hp 840g6\\OneDrive\\Desktop\\Python\\Class 14\\mahpara.txt' mode='r' encoding='cp1252'>

# %% [markdown]
# A UTF-8  ا

# %%
open("mahpara.txt")
# Out:
# <_io.TextIOWrapper name='mahpara.txt' mode='r' encoding='cp1252'>

# %%
f = open("mahpara.txt")
f
# Out:
# <_io.TextIOWrapper name='mahpara.txt' mode='r' encoding='cp1252'>

# %%
f = open("mahpara.txt")
print(f)
print(f.read())

f.close()
# Out:
# <_io.TextIOWrapper name='mahpara.txt' mode='r' encoding='cp1252'>
# Mahpara Badar
# Biomedical Engineer
# Data Science and Artificial Intelligence Enthusiast
# NED University of Engineering and Technology

# %%
f = open("mahpara.txt")
# print(f)
print(f.read())

f.close()
# Out:
# Mahpara Badar
# Biomedical Engineer
# Data Science and Artificial Intelligence Enthusiast
# NED University of Engineering and Technology

# %%
f = open("mahpara.txt")
# print(f)
print(f.readline())

f.close()
# Out:
# Mahpara Badar

# %%
f = open("mahpara.txt")
# print(f)
print(f.readlines())

f.close()
# Out:
# ['Mahpara Badar\n', 'Biomedical Engineer\n', 'Data Science and Artificial Intelligence Enthusiast\n', 'NED University of Engineering and Technology\n']

# %%
list(open("mahpara.txt"))  # no need to close here b/c we haven't given it connectivity to object
# Out:
# ['Mahpara Badar\n',
#  'Biomedical Engineer\n',
#  'Data Science and Artificial Intelligence Enthusiast\n',
#  'NED University of Engineering and Technology\n']

# %% [markdown]
# # "with" Block

# %%
## no need to close ##

with open("./mahpara.txt") as file:
    y = file.readlines()
    print(y)
# Out:
# ['Mahpara Badar\n', 'Biomedical Engineer\n', 'Data Science and Artificial Intelligence Enthusiast\n', 'NED University of Engineering and Technology\n']

# %% [markdown]
# ### Applying File Modes

# %%
with open("./mahpara.txt", mode = 'r') as file:   # r = read only
    y = file.readlines()
    print(y)
# Out:
# ['Mahpara Badar\n', 'Biomedical Engineer\n', 'Data Science and Artificial Intelligence Enthusiast\n', 'NED University of Engineering and Technology\n']

# %%
# w = write

with open("./mahpara.txt", mode ='w') as file:
    y = file.readlines()           # don't use read or readlines for 'w'
    print(y)
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[31], line 4
#       1 # w = write
#       3 with open("./mahpara.txt", mode ='w') as file:
# ----> 4     y = file.readlines()           # don't use read or readlines for 'w'
#       5     print(y)
#
# UnsupportedOperation: not readable

# %%
# w = write

with open("./mahpara.txt", mode = 'r') as file:
    file.write("aaaaaaaaaaaaaaaaaaaaaaaaaaaaa")
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[32], line 2
#       1 with open("./mahpara.txt", mode = 'r') as file:
# ----> 2     file.write("aaaaaaaaaaaaaaaaaaaaaaaaaaaaa")
#
# UnsupportedOperation: not writable

# %%
# r+ = read and write, w+ = write and read

with open("./mahpara.txt", mode ='r+') as file:
    y = file.readlines()           
    print("before: ====== ", y)
# Out:
# before: ======  ['a\n', 'b\n', 'c\n', 'd']

# %%
# r+ = read and write, w+ = write and read

with open("./mahpara.txt", mode ='r+') as file:
    y = file.readlines()           
    print("before: ====== ", y)
    file.write("\nPakistan zinda bad")
    y = file.readlines()
    print("after: ====== ", y)
# Out:
# before: ======  ['a\n', 'b\n', 'c\n', 'd\n', 'Pakistan zinda bad\n', 'Pakistan zinda bad']
# after: ======  []

# %%
# r+ = read and write, w+ = write and read

with open("./mahpara.txt", mode ='r+') as file:
    y = file.readlines()           
    print("before: ====== ", y)
    file.write("\nNED University")
    file.seek(0)           # to move the cursor again to zero position/then it will read from starting
    y = file.readlines()
    print("after: ====== ", y)
# Out:
# before: ======  ['a\n', 'b\n', 'c\n', 'd\n', 'Pakistan zinda bad\n', 'Pakistan zinda bad\n', 'Pakistan zinda bad\n', 'NED University']
# after: ======  ['a\n', 'b\n', 'c\n', 'd\n', 'Pakistan zinda bad\n', 'Pakistan zinda bad\n', 'Pakistan zinda bad\n', 'NED University\n', 'NED University']

# %%
# r+ = read and write, w+ = write and read

with open("./mahpara.txt", mode ='r+') as file:
    y = file.readlines()           
    print("before: ====== ", y)
    file.write("\nHello World")
    file.seek(0)           # to move the cursor again to zero position/then it will read from starting
    y = file.readlines()
    print("after: ====== ", y)
# Out:
# before: ======  ['a\n', 'b\n', 'c\n', 'd\n', 'Pakistan zinda bad\n', 'Pakistan zinda bad\n', 'Pakistan zinda bad\n', 'NED University\n', 'NED University']
# after: ======  ['a\n', 'b\n', 'c\n', 'd\n', 'Pakistan zinda bad\n', 'Pakistan zinda bad\n', 'Pakistan zinda bad\n', 'NED University\n', 'NED University\n', 'Hello World']

# %%
# r+ = read and write, w+ = write and read

with open("./mahpara.txt", mode ='r+') as file:
    file.write("\nHello World")
    file.seek(0)           # to move the cursor again to zero position/then it will read from starting
    y = file.readlines()
    print("after: ====== ", y)
# Out:
# after: ======  ['\n', 'Hello Worldstan zinda bad\n', 'Pakistan zinda bad\n', 'Pakistan zinda bad\n', 'NED University\n', 'NED University\n', 'Hello World']

# %%
# r+ = read and write, w+ = write and read

with open("./mahpara.txt", mode ='r+') as file:
    file.write("\nHello World")
    file.seek(0)           # to move the cursor again to zero position/then it will read from starting
    y = file.readlines()
    print("after: ====== ", y)
# Out:
# after: ======  ['\n', 'Hello Worlda bad\n', 'NED University\n']

# %%
# r+ = read and write, w+ = write and read

with open("./mahpara.txt", mode ='r+') as file:
    file.write("Hello World")
    file.seek(0)           # to move the cursor again to zero position/then it will read from starting
    y = file.readlines()
    print("after: ====== ", y)
# Out:
# after: ======  ['Hello Worldlda bad\n', 'NED University\n']

# %% [markdown]
# # Append Mode

# %%
with open("xyz.txt", "a+") as f:
    f.write("A")

# %%
with open("xyz.txt", "a+") as f:
    f.write("A")
    print(f.read())

# %%
with open("xyz.txt", "a+") as f:  # a = append, always adds in the last
    f.write("A")
    f.seek(0)
    print(f.read())
# Out:
# AAAAAAAABAA

# %%
with open("xyz.txt", "a+") as f:  # a = append, a+ = append and read, always adds in the last
    f.write("\nhello world")
    f.seek(0)
    print(f.read())
# Out:
# AAAAAAAABAA\hello world
# hello world

# %%
# only using "w" will overwrite the whole file

with open("xyz.txt", "w") as f: 
    f.write("hello world")

# %%
with open("xyz.txt", "r") as f:
    print(f.read())
# Out:
# hello world

# %%
with open("xyz.txt", "w") as f: 
    f.write("Mahpara Badar")

# %%
with open("xyz.txt", "r") as f:
    print(f.read())
# Out:
# Mahpara Badar

# %%
with open("C:\\Users\\hp 840g6\\OneDrive\\Desktop\\Python\\Class 14\\closing11.txt") as f: 
    data = f.read()
    print(data)
# Out:
# 01SEP2023|786|0813|786 Invest Ltd|5.0|5|5|5|15500|5|||
# 01SEP2023|ABL|0807|Allied Bank LtdXD|70.0|70|69|69|300000|69.5|||
# 01SEP2023|ABOT|0823|Abbott Lab.|364.0|369.89|364|369.89|400|361|||
# 01SEP2023|ACPL|0804|Attock Cement|79.7|79.75|79|79.63|2010|78.46|||
# 01SEP2023|ADMM|0829|Artistic Denim|52.5|53.29|52.5|53.29|2500|53.18|||
# 01SEP2023|AGHA|0808|Agha Steel Ind.|9.78|9.78|9.4|9.47|152945|9.5|||
# 01SEP2023|AGHA-NOV|40|Agha Steel Ind.|0.0|0|0|10.03|0|10.08|||
# 01SEP2023|AGHA-OCT|40|Agha Steel Ind.|0.0|0|0|9.84|0|9.89|||
# 01SEP2023|AGHA-SEP|40|Agha Steel Ind.|0.0|0|0|9.65|0|9.51|||
# 01SEP2023|AGIC|0812|Ask.Gen.Insur.|14.07|14.07|13.8|14|18000|14|||
# 01SEP2023|AGIL|0802|Agriautos Ind.|59.0|59|54.58|55.67|43500|59|||
# 01SEP2023|AGL|0805|Agritech Limited|5.9|6.19|5.7|6.12|357500|5.79|||
# 01SEP2023|AGL-NOV|40|Agritech Limited|0.0|0|0|6.48|0|6.15|||
# 01SEP2023|AGL-OCT|40|Agritech Limited|0.0|0|0|6.36|0|6.03|||
# ...

# %%
import pandas as pd

df = pd.read_csv("C:\\Users\\hp 840g6\\OneDrive\\Desktop\\Python\\Class 14\\closing11.txt", sep = "|")
df
# Out:
#      01SEP2023      786  0813     786 Invest Ltd     5.0       5     5.1  \
# 0    01SEP2023      ABL   807  Allied Bank LtdXD   70.00   70.00   69.00
# 1    01SEP2023     ABOT   823        Abbott Lab.  364.00  369.89  364.00
# 2    01SEP2023     ACPL   804      Attock Cement   79.70   79.75   79.00
# 3    01SEP2023     ADMM   829     Artistic Denim   52.50   53.29   52.50
# 4    01SEP2023     AGHA   808    Agha Steel Ind.    9.78    9.78    9.40
# ..         ...      ...   ...                ...     ...     ...     ...
# 602  01SEP2023      WTL   828  WorldCall Telecom    1.15    1.16    1.13
# 603  01SEP2023  WTL-NOV    40  WorldCall Telecom    0.00    0.00    0.00
# 604  01SEP2023  WTL-SEP    40  WorldCall Telecom    1.13    1.19    1.13
# 605  01SEP2023     YOUW   831     Yousuf Weaving    2.70    2.85    2.70
# 606  01SEP2023      ZTL   831     Zephyr Textile   10.39   10.39   10.39
#
#         5.2     15500     5.3  Unnamed: 10  Unnamed: 11  Unnamed: 12
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimage

img = mpimage.imread("./files/a.jpg")
#print(img.shape)#
plt.imshow(img)  # display image
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimage

img = mpimage.imread("mountains.jpg")
#print(img.shape)#
plt.imshow(img)  # display image
